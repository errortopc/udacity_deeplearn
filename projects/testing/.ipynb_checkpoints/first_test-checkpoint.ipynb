# %%
print ("Hello World")
# Out:
# Hello World

# %%
x=2

# %%
if x == 1:
    print (x)
else:
    print (3*x)
# Out:
# 30

# %% [markdown]
# # Test
# Das ist ein Text
# Hallo

# %% [markdown]
# Math mode with ''$$''

# %% [markdown]
# $$
# y = \frac{a}{b+c}
# $$

# %% [markdown]
# measure runtime with:
#
# ''%%timeit''  --> whole cell
#
# ''$timeit [methodecall]'' --> single method

# %%
def testrun(x):
    y = 0
    for a in range(1,x):
        y = y * 5
# %timeit testrun(5)
# Out:
# 723 ns ± 2.97 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)

# %%
# %matplotlib inline

import matplotlib.pyplot as mplot
import numpy as np
from math import pi,sin

x = np.linspace(0,2*pi,100)
for w in range(2,6,1):
    print(w)
    mplot.plot(x, np.sin(pi*x))
    mplot.plot(x, np.sin(pi*x)*2)
# Out:
# 2
# 3
# 4
# 5
